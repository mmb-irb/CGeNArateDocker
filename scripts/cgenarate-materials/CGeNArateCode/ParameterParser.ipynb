# %%
import numpy as np

# %% [markdown]
# DTetramer and KTetramer are 256x16 and 256x16x3, respectively. There are 256 tetramers, ordered alphabetically as provided below, with each tetramer containing 16 interactions, ordered as below. In KTetramer, the three values are the order 2,3 and 4 energy constants.
#
# Where it applies, W means Watson strand, and C means Crick strand;  5 means on the 5' end of the Watson strand, while 3 means 3' end of the Watson strand (note that Angle_C5 is in the 5' end of the Watson strand, while being itself in the Crick strand, and therefore 3' end of the Crick strand)
#
# Interactions occurring in two tetramers are obtained by averaging between the two. The interactions that have to be scaled by 1/2 are marked in RelativeValues.
# While all 256 tetramers are recorded in the file, complimentary tetramers share the same parameter set. parselist is an index slicing that transforms the parameter set from a sequence (AACC) to its complimentary (GGTT)
#
# DLong and KLong contain the 4 distant interactions in a similar manner, ordered as below.

# %%
# Energy units are Kcal/mol, distance units are Ångstroms, angle units are radians

# Tetramers = [a+b+c+d for a in 'ACGT' for b in 'ACGT' for c in 'ACGT' for d in 'ACGT']
# InteractionTetramers = ["Bond_W","Bond_C","Angle_W5","Angle_W3","Angle_C5","Angle_C3",
#         "3m","2m_5","2m_3","1m","bp_5","bp_3","1p","2p_5","2p_3","3p"]
# parselist = [1,0,5,4,3,2,6,8,7,9,11,10,12,14,13,15]
# RelativeValues = [1,1,2,2,2,2,1,2,2,1,2,2,1,2,2,1]

KTetramer = np.loadtxt("input/MyK.txt")/418.4
KTetramer = KTetramer.reshape((-1, 16, 3))

DTetramer = np.loadtxt("input/MyD.txt")

# LongInteractions = ["5m","4m","4p","5p"]

KLong = np.loadtxt("input/MyKLong.txt")/418.4

DLong = np.loadtxt("input/MyDLong.txt")

# %% [markdown]
# ![TetramerInteractions.png](attachment:TetramerInteractions.png)
